# %% [markdown]
# # Tugas 1 : Data Integration

# %% [markdown]
# ## Sumber Data : UCI Machine Learning Repository - Facebook metrics Data Set

# %%
import pandas as pd

# %%
data1 = pd.read_csv('E:\kuliah\data mining statistika\data integration_06211640000033\Tugas 1\datatugas1_1.csv',sep=';')
data2 = pd.read_csv('E:\kuliah\data mining statistika\data integration_06211640000033\Tugas 1\datatugas1_2.csv',sep=';')

data_merge = pd.merge(data1,data2,on=['Page total likes','Type'])
data_merge.head()

data_merge.to_csv('E:\kuliah\data mining statistika\data integration_06211640000033\Tugas 1\Facebook_dataset1.csv')

# %%
data_merge
# Out:
#       Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0               139441  Photo         2          12             4          3
# 1               139441  Photo         2          12             4          3
# 2               139441  Photo         2          12             4          3
# 3               139441  Photo         2          12             4          3
# 4               139441  Photo         2          12             4          3
# 5               139441  Photo         2          12             4          3
# 6               139441  Photo         2          12             4          3
# 7               139441  Photo         2          12             4          3
# 8               139441  Photo         2          12             4          3
# 9               139441  Photo         2          12             4          3
# 10              139441  Photo         3          12             3          3
# ...

# %%
data1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %%
data2
# Out:
#      Page total likes    Type  Lifetime Post Consumptions  \
# 0              139441   Photo                         159
# 1              139441  Status                        1674
# 2              139441   Photo                         154
# 3              139441   Photo                        1119
# 4              139441   Photo                         580
# 5              139441  Status                        1389
# 6              139441   Photo                         364
# 7              139441   Photo                         305
# 8              139441  Status                        1692
# 9              139441   Photo                         250
# 10             139441  Status                        4540
# 11             139441   Photo                         145
# 12             139441   Photo                         133
# 13             139441   Photo                         168
# 14             138414   Photo                         417
# ...

# %%
data3 = pd.read_csv('E:\kuliah\data mining statistika\data integration_06211640000033\Tugas 1\datatugas1_3.csv',sep=';')
data4 = pd.read_csv('E:\kuliah\data mining statistika\data integration_06211640000033\Tugas 1\datatugas1_4.csv',sep=';')

data_concat = pd.concat([data3,data4])
data_concat.head()

data_concat.to_csv('E:\kuliah\data mining statistika\data integration_06211640000033\Tugas 1\Facebook_dataset2.csv')

# %%
data_concat
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %%
data3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %%
data4
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              129600   Photo         1           7             7          6
# 1              129600   Photo         1           7             6         11
# 2              129600   Photo         3           7             6          5
# 3              129600  Status         2           7             5         12
# 4              129600   Photo         3           7             5          3
# 5              129600   Photo         2           7             4         12
# 6              129600   Photo         1           7             4          6
# 7              129600   Photo         1           7             3         13
# 8              129600   Photo         2           7             3          1
# 9              129600   Photo         3           7             2         13
# 10             129600   Photo         2           7             2          7
# ...
