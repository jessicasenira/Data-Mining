# %% [markdown]
# # Tugas 1 : Data Integration

# %% [markdown]
# ## Sumber Data : UCI Machine Learning Repository - Facebook metrics Data Set

# %%
import pandas as pd

# %%
data1 = pd.read_csv('E:\kuliah\data mining statistika\data integration_06211640000033\datatugas1_1.csv',sep=';')
data2 = pd.read_csv('E:\kuliah\data mining statistika\data integration_06211640000033\datatugas1_2.csv',sep=';')

data_merge = pd.merge(data1,data2,on=['Page total likes','Type'])
data_merge.head()

data_merge.to_csv('E:\kuliah\data mining statistika\data integration_06211640000033\Facebook_dataset1.csv')

# %%
data_merge.head()
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 1            139441  Photo         2          12             4          3
# 2            139441  Photo         2          12             4          3
# 3            139441  Photo         2          12             4          3
# 4            139441  Photo         2          12             4          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                       2752                             5091
# 2   0.0                       2752                             5091
# 3   0.0                       2752                             5091
# 4   0.0                       2752                             5091
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
data1.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# 0                     178                      109
# ...

# %%
data2.head()
# Out:
#    Page total likes    Type  Lifetime Post Consumptions  \
# 0            139441   Photo                         159
# 1            139441  Status                        1674
# 2            139441   Photo                         154
# 3            139441   Photo                        1119
# 4            139441   Photo                         580
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                               3078
# 1                                              11710
# 2                                               2812
# 3                                              61027
# 4                                               6228
#
#    Lifetime Post reach by people who like your Page  \
# 0                                              1640
# 1                                              6112
# 2                                              1503
# 3                                             32048
# ...

# %%
data3 = pd.read_csv('E:\kuliah\data mining statistika\data integration_06211640000033\datatugas1_3.csv',sep=';')
data4 = pd.read_csv('E:\kuliah\data mining statistika\data integration_06211640000033\datatugas1_4.csv',sep=';')

data_concat = pd.concat([data3,data4])
data_concat.head()

data_concat.to_csv('E:\kuliah\data mining statistika\data integration_06211640000033\Facebook_dataset2.csv')

# %%
data_concat.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data3.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0                       2752                             5091
# 1     0                      10460                            19057
# 2     0                       2413                             4373
# 3     1                      50128                            87991
# 4     0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data4.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            129600   Photo         1           7             7          6
# 1            129600   Photo         1           7             6         11
# 2            129600   Photo         3           7             6          5
# 3            129600  Status         2           7             5         12
# 4            129600   Photo         3           7             5          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   1.0                       5848                             9068
# 1   0.0                      26944                            43464
# 2   0.0                       5292                             9321
# 3   1.0                      15576                            27513
# 4   0.0                      54256                            82011
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...
